# %%
from emotion_detection import emotion_detector
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from emotion_detection import emotion_detector
#
# ImportError: cannot import name 'emotion_detector' from 'emotion_detection' (d:\IBM_Projects\final_project\emotion_detection.py)

# %%
emotion_detector("I am happy")
